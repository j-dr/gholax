# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from gholax.util.model import Model
from gholax.util.postprocess_chain import load_samples_from_checkpoint
import getdist
from getdist import plots, MCSamples

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = Model('../example_configs/example_lsst.yaml')

# %%
output_file = f'/global/cfs/projectdirs/desi/users/jderose/shear_x_rsd_mock_challenge/chains/noiseless_sims/fid_lsst_5sbins_y10_nbarpb5_all_lcdm_fixednu_c_kk_no_ia_spline_s0-1-2-3-4_spline_N_2_spline_D_1.5_byk_k2_pade_baryon_spline_N_3_spline_D_0.6_kmm1.0_lcto3_no_am_ell_min_kk_0_NUTS.txt'
samples, params_best_fit, reference_params, param_names, optimization_results = load_samples_from_checkpoint(output_file, model, 'Nx2PTAngularPowerSpectrum', sampler='NUTS', smooth_scale=0.5)
# Out:
# Removed no burn in

# %%
g = plots.get_subplot_plotter()
g.triangle_plot([samples], params=['s8', 'omegam'],
                filled=True, contour_colors=['C0'],
                 markers={'s8':params_best_fit['s8'], 'omegam':params_best_fit['omegam']})

f = plt.gcf()

f.set_figheight(6)
f.set_figwidth(6)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
